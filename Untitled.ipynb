# %%
x = 10
print(type(x))
# Out:
# <class 'int'>

# %%
y = 3.5
print(type(y))
# Out:
# <class 'float'>

# %%
name = "Python"
print(type(name))
# Out:
# <class 'str'>

# %%
numbers = [1, 2, 3]
print(type(numbers))
# Out:
# <class 'list'>

# %%
data = (10, 20)
print(type(data))
# Out:
# <class 'tuple'>

# %%
values = {1, 2, 3}
print(type(values))
# Out:
# <class 'set'>

# %%
student = {"name": "Bala", "age": 21}
print(type(student))
# Out:
# <class 'dict'>

# %%
result = True
print(type(result))
# Out:
# <class 'bool'>

# %%
x = None
print(type(x))
# Out:
# <class 'NoneType'>
