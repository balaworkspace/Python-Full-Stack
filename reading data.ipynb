# %%
import pandas as pd
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\BALAMURUGAN\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\BALAMURUGAN\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\Users\BALAMURUGAN\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
# ...

# %%
pip install numpy==2.2.1
# Out:
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --------- ------------------------------ 2.9/12.6 MB 13.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.5/12.6 MB 12.9 MB/s eta 0:00:01
#    ------------------------- -------------- 8.1/12.6 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.7/12.6 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 11.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.1
#     Uninstalling numpy-2.4.1:
#       Successfully uninstalled numpy-2.4.1
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\BALAMURUGAN\anaconda3\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\BALAMURUGAN\anaconda3\Lib\site-packages\~umpy'.
# ...

# %%
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\BALAMURUGAN\OneDrive\Documents\Data - Base.csv")

# %%
df
# Out:
#          NAME Age  Gender Type of Graduation/Post Graduation Marital status  \
# 0      parida  25  Female            Masters in data science      Unmarried
# 1      shreej  29  Female                         BSc or MSc      Unmarried
# 2      ms6744  27  Female                       B.E / B-Tech      Unmarried
# 3      aswalu  22    Male                       B.E / B-Tech      Unmarried
# 4      aniket  22    Male                              BA/MA      Unmarried
# ...       ...  ..     ...                                ...            ...
# 21251  amitmk  25    Male                       B.E / B-Tech      Unmarried
# 21252  Seshag  31    Male                              B.ARC        Married
# 21253  melbin  26    Male                       B.E / B-Tech      Unmarried
# 21254  Nihal0  24    Male                                MBA      Unmarried
# 21255  Abbind  28    Male                                MBA        Married
#
#       Mode of interview given by candidate?  \
# ...

# %%
print(df.head())
# Out:
#      NAME Age  Gender Type of Graduation/Post Graduation Marital status  \
# 0  parida  25  Female            Masters in data science      Unmarried
# 1  shreej  29  Female                         BSc or MSc      Unmarried
# 2  ms6744  27  Female                       B.E / B-Tech      Unmarried
# 3  aswalu  22    Male                       B.E / B-Tech      Unmarried
# 4  aniket  22    Male                              BA/MA      Unmarried
#
#   Mode of interview given by candidate?         Pre Interview Check  \
# 0                                Mobile  Proceed with the Interview
# 1                                Mobile  Proceed with the Interview
# 2                                Mobile  Proceed with the Interview
# 3                                Laptop  Proceed with the Interview
# 4                                Mobile  Proceed with the Interview
#
#             Fluency in English based on introduction  \
# 0  Able to speak sentences in a clear/coherent wa...
# ...

# %%
print(df.tail())
# Out:
#          NAME Age Gender Type of Graduation/Post Graduation Marital status  \
# 21251  amitmk  25   Male                       B.E / B-Tech      Unmarried
# 21252  Seshag  31   Male                              B.ARC        Married
# 21253  melbin  26   Male                       B.E / B-Tech      Unmarried
# 21254  Nihal0  24   Male                                MBA      Unmarried
# 21255  Abbind  28   Male                                MBA        Married
#
#       Mode of interview given by candidate?  \
# 21251                                Mobile
# 21252                                Laptop
# 21253                                Mobile
# 21254                                Mobile
# 21255                                Mobile
#
#                            Pre Interview Check  \
# 21251               Proceed with the Interview
# 21252               Proceed with the Interview
# 21253               Proceed with the Interview
# 21254  Rehire - Have worked with Byjus earlier
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21256 entries, 0 to 21255
# Data columns (total 52 columns):
#  #   Column                                                                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                                                                             --------------  -----
#  0   NAME                                                                                                                                               21256 non-null  object
#  1   Age                                                                                                                                                21256 non-null  object
#  2   Gender                                                                                                                                             21256 non-null  object
# ...

# %%
print(df.describe())
# Out:
#        Confidence based on Introduction (English).1  \
# count                                  21256.000000
# mean                                       2.218950
# std                                        0.642017
# min                                        1.000000
# 25%                                        2.000000
# 50%                                        2.000000
# 75%                                        3.000000
# max                                        3.000000
#
#        Confidence based on the topic given  .1  \
# count                             21256.000000
# mean                                  2.004610
# std                                   0.953779
# min                                   0.000000
# 25%                                   2.000000
# 50%                                   2.000000
# 75%                                   3.000000
# max                                   3.000000
#
#        Confidence Based on the PPT Question.1  \
# ...

# %%
print(df["Age"])
# Out:
# 0        25
# 1        29
# 2        27
# 3        22
# 4        22
#          ..
# 21251    25
# 21252    31
# 21253    26
# 21254    24
# 21255    28
# Name: Age, Length: 21256, dtype: object

# %%
print(df.columns)
# Out:
# Index(['NAME', 'Age', 'Gender', 'Type of Graduation/Post Graduation',
#        'Marital status', 'Mode of interview given by candidate?',
#        'Pre Interview Check', 'Fluency in English based on introduction',
#        'Confidence based on Introduction (English)',
#        'Confidence based on the topic given  ',
#        'Confidence Based on the PPT Question',
#        'Confidence based on the sales scenario',
#        'Structured Thinking (In regional only)',
#        'Structured Thinking Based on the PPT Question',
#        'Structured Thinking( Call pitch)',
#        'Regional fluency based on the topic given  ',
#        'Regional fluency Based on the PPT Question',
#        'Regional fluency based on the  sales scenario',
#        'Does the candidate has mother tongue influence while speaking english.',
#        'Has acquaintance in Company and has spoken to him/her before applying?',
#        'Candidate Status', 'Last Fixed CTC (lakhs) ', 'Currently Employed',
# ...

# %%
print(df["NAME"])
# Out:
# 0        parida
# 1        shreej
# 2        ms6744
# 3        aswalu
# 4        aniket
#           ...
# 21251    amitmk
# 21252    Seshag
# 21253    melbin
# 21254    Nihal0
# 21255    Abbind
# Name: NAME, Length: 21256, dtype: object

# %%
print(df.loc[0])
# Out:
# NAME                                                                                                                                                                                            parida
# Age                                                                                                                                                                                                 25
# Gender                                                                                                                                                                                          Female
# Type of Graduation/Post Graduation                                                                                                                                             Masters in data science
# ...

# %%
print(df.loc[2])
# Out:
# NAME                                                                                                                                                                                            ms6744
# Age                                                                                                                                                                                                 27
# Gender                                                                                                                                                                                          Female
# Type of Graduation/Post Graduation                                                                                                                                                        B.E / B-Tech
# ...

# %%
print(df.loc["12"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(df.loc["12"])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1432, in _LocIndexer._getitem_axis(self, key, axis)
#    1430 # fall thru to straight lookup
#    1431 self._validate_key(key, axis)
# -> 1432 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1382, in _LocIndexer._get_label(self, label, axis)
#    1380 def _get_label(self, label, axis: AxisInt):
# ...

# %%
print(df.info())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(df.info())
#
# NameError: name 'df' is not defined
